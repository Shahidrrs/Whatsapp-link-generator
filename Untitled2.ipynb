# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahidrrs/Nutribone/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.4.0)
# Requirement already satisfied: jupytext in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.19.3)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.20 in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.1.23)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaggle) (26.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: markdown-it-py>=1.0 in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (4.2.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (0.6.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (5.10.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (6.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (2026.5.20)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=1.0->jupytext->kaggle) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2026.5.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (4.10.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->jupytext->kaggle) (4.15.0)

# %%
# !unzip "/content/archive (4).zip" -d /content/dataset
# Out:
# unzip:  cannot find or open /content/archive (4).zip, /content/archive (4).zip.zip or /content/archive (4).zip.ZIP.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset/1.archive...
# 100%|██████████| 1.17G/1.17G [00:14<00:00, 86.4MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset/versions/1

# %%
import os

base = path
print(os.listdir(base))
# Out:
# ['OS Collected Data']

# %%
import os

dataset_path = os.path.join(base, "OS Collected Data")
print(os.listdir(dataset_path))
# Out:
# ['Normal', 'Osteoporosis', 'Osteopenia']

# %%
import os

dataset_path = os.path.join(base, "OS Collected Data")

print(os.listdir(dataset_path))
# Out:
# ['Normal', 'Osteoporosis', 'Osteopenia']

# %%
from PIL import Image
import os

dataset_path = os.path.join(base, "OS Collected Data")

# Example: open first image in Normal
normal_folder = os.path.join(dataset_path, 'Normal')
first_image = os.listdir(normal_folder)[0]
image_path = os.path.join(normal_folder, first_image)

img = Image.open(image_path)
img.show()

# %%
import numpy as np
from PIL import Image

categories = ['Normal', 'Osteopenia', 'Osteoporosis']
data = []
labels = []

for category in categories:
    folder_path = os.path.join(dataset_path, category)
    for file in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file)
        try:
            img = Image.open(file_path).convert('RGB').resize((224,224))
            data.append(np.array(img))
            labels.append(category)
        except:
            print("Error loading", file_path)

data = np.array(data)
labels = np.array(labels)
print("Data shape:", data.shape)
print("Labels shape:", labels.shape)
# Out:
# Data shape: (1947, 224, 224, 3)
# Labels shape: (1947,)

# %%
print(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7A392C217380>

# %%
import matplotlib.pyplot as plt
import random

# randomly ek image index choose kro
idx = random.randint(0, len(data) - 1)

# image aur label load kro
img = data[idx]
label = labels[idx]

plt.imshow(img.astype('uint8'))
plt.title(f"Label: {label}")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(223.5), np.float64(223.5), np.float64(-0.5))

# %%
import matplotlib.pyplot as plt
import random

idx = random.randint(0, len(data) - 1)

img = data[idx]
label = labels[idx]

plt.imshow(img.astype('uint8'))
plt.title(f"Label: {label}")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(223.5), np.float64(223.5), np.float64(-0.5))

# %%
dataset_path = "/kaggle/input/multi-class-knee-osteoporosis-x-ray-dataset/OS Collected Data"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# Ensure the clean path variable is utilized correctly
dataset_path = os.path.join(path, "OS Collected Data")

print(f"Verifying dataset_path: {dataset_path}")
if not os.path.exists(dataset_path):
    print(f"Error: The directory '{dataset_path}' does not exist.")
else:
    print(f"Success: The directory '{dataset_path}' exists.")
    try:
        contents = os.listdir(dataset_path)
        print(f"Contents of '{dataset_path}': First 5 items: {contents[:5]}")
    except Exception as e:
        print(f"Error checking path contents: {e}")

# High-resolution input processing: Crucial for microscopic bone textures
train_datagen = ImageDataGenerator(
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    brightness_range=[0.85, 1.15],
    horizontal_flip=True,
    fill_mode='nearest'
)

# Validation generator stays clean (no distortions to corrupt verification records)
val_datagen = ImageDataGenerator(
    validation_split=0.2
)

# Target resolution scaled from 224 to 300 to provide double the structural clarity
train_gen = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(300, 300),
    batch_size=16,           # Lowered batch size to prevent GPU out-of-memory errors at 300x300
    class_mode='categorical',
    subset='training'
)

val_gen = val_datagen.flow_from_directory(
    dataset_path,
    target_size=(300, 300),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Verifying dataset_path: /root/.cache/kagglehub/datasets/mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset/versions/1/OS Collected Data
# Success: The directory '/root/.cache/kagglehub/datasets/mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset/versions/1/OS Collected Data' exists.
# Contents of '/root/.cache/kagglehub/datasets/mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset/versions/1/OS Collected Data': First 5 items: ['Normal', 'Osteopenia', 'Osteoporosis']
# Found 1559 images belonging to 3 classes.
# Found 388 images belonging to 3 classes.

# %%
#model traning
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# %%
base = EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

base.trainable = False   # freeze feature extractor

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model

# 1. Initialize the core pre-trained base model
base = EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)
base.trainable = False   # Keep features locked to prevent unstable gradients

# 2. Setup the functional pipeline with automatic image normalization
inputs = tf.keras.Input(shape=(224, 224, 3))
preprocessed_inputs = tf.keras.applications.efficientnet.preprocess_input(inputs)

# 3. Connect the pipeline through the base and your updated classification head
x = base(preprocessed_inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)              # Safe regularization factor
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)              # Safe regularization factor
output = Dense(train_gen.num_classes, activation='softmax')(x)

# 4. Construct the complete final Model
model = Model(inputs=inputs, outputs=output)

# 5. Compile with the stable medical training learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,378,278 (16.70 MB)
#  Trainable params: 328,707 (1.25 MB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import numpy as np
from sklearn.utils import class_weight

# =====================================================================
# 1. CALIBRATED CLASS WEIGHTS
# =====================================================================
class_labels = train_gen.classes
unique_classes = np.unique(class_labels)

raw_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=unique_classes,
    y=class_labels
)

# Smoothing balance: Keeps Osteopenia highly competitive without flooding precision metrics
smoothed_weights = (raw_weights + 1.0) / 2.0
class_weight_dict = dict(zip(unique_classes, smoothed_weights))
print(f"Calibrated Smoothed Class Weights: {class_weight_dict}")

# =====================================================================
# 2. BUILD HIGH-RESOLUTION MODEL (EfficientNetB3)
# =====================================================================
print("\nInitializing EfficientNetB3 Base Core Engine...")
inputs = layers.Input(shape=(300, 300, 3))

# Initializing B3 for deep macro-structural diagnostic tracking
base_model = tf.keras.applications.EfficientNetB3(
    include_top=False,
    weights='imagenet',
    input_tensor=inputs
)
base_model.trainable = False  # Freeze backbone for initial warmup phase

# Specialized dense processing block with regularization layers
x = layers.GlobalAveragePooling2D()(base_model.output)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(3, activation='softmax')(x)

model = models.Model(inputs, outputs)

# =====================================================================
# 3. RUNTIME SYSTEM CALLBACKS
# =====================================================================
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-7,
    verbose=1
)

early_stop_stage1 = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

early_stop_stage2 = EarlyStopping(
    monitor='val_loss',
    patience=7,
    restore_best_weights=True,
    verbose=1
)

# =====================================================================
# 4. STAGE 1: CLASSIFICATION WARMUP
# =====================================================================
print("\nStarting Stage 1: Top-Layer Classification Warmup...")
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=12,
    class_weight=class_weight_dict,
    callbacks=[lr_scheduler, early_stop_stage1]
)

# =====================================================================
# 5. STAGE 2: DEEP MULTI-LAYER FINE-TUNING VIA ADAMW
# =====================================================================
print("\n--- Transitioning to Stage 2: Deep 80-Layer Fine-Tuning ---")

base_model.trainable = True
# Unfreeze the top 80 layers of EfficientNetB3 for rich contextual tuning
for layer in base_model.layers[:-80]:
    layer.trainable = False
print("Successfully isolated and unfrozen the top 80 feature layers of EfficientNetB3.")

# Compile using AdamW for strict regularization to stabilize fine-tuning boundaries
model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=3e-5, weight_decay=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("Fine-tuning deep feature blocks under high-resolution conditions...")
history_ft = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=35,
    class_weight=class_weight_dict,
    callbacks=[lr_scheduler, early_stop_stage2]
)

# Save the final optimized architecture weights
model.save("nutribone_highres_effnetB3_model.h5")
print("\n80-90% Target Range Model Training Complete and Saved Successfully!")
# Out:
# Starting Fast Warmup Loop (Stage 1)...
# Epoch 1/2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1723/2522505476.py in <cell line: 0>()
#      25 # =====================================================================
#      26 print("\nStarting Fast Warmup Loop (Stage 1)...")
# ---> 27 history = model.fit(
#      28     train_gen,
#      29     validation_data=val_gen,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     243                 if spec_dim is not None and dim is not None:
#     244                     if spec_dim != dim:
# --> 245                         raise ValueError(
#     246                             f"Input {input_index} with name '{spec.name}' of "
#     247                             f"layer '{layer_name}' is incompatible with the "
#
# ValueError: Input 0 with name 'input_layer_1' of layer 'functional' is incompatible with the layer: expected shape=(None, 224, 224, 3), found shape=(None, 300, 300, 3)

# %%
model.save("nutribone_effnet_model.h5")
print("Model Saved!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1723/1058177781.py in <cell line: 0>()
# ----> 1 model.save("nutribone_effnet_model.h5")
#       2 print("Model Saved!")
#
# NameError: name 'model' is not defined

# %%
# Stage 2: Perfectly Sequenced Evaluation
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# =====================================================================
# 1. PLOT METRIC TRENDS FROM MODEL TRAINING
# =====================================================================
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(); plt.title('Loss Progression')

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.legend(); plt.title('Accuracy Progression')
plt.show()

# =====================================================================
# 2. BULLETPROOF 1-TO-1 ALIGNED PREDICTION BLOCK
# =====================================================================
print("\nCalculating perfectly aligned 1-to-1 validation metrics...")

# 1. Force sequential ordering AND clean individual step sizing
val_gen.shuffle = False
val_gen.batch_size = 1   # Fixes the remainder batch mismatch
val_gen.reset()

# 2. Generate clean, sequential predictions matching disk order
preds = model.predict(val_gen, steps=len(val_gen), verbose=1)
y_pred = np.argmax(preds, axis=1)
y_true = val_gen.classes
class_names = list(val_gen.class_indices.keys())

# 3. Print your authentic classification metrics
print("\n--- Real Aligned Classification Report ---")
print(classification_report(y_true, y_pred, target_names=class_names))

# 4. Plot the accurate Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('True Aligned Confusion Matrix')
plt.show()
# Out:
# Notice: Training 'history' log variable not found in memory. Skipping training trend charts...
#
# Loading successfully saved model weights from your local disk...
# Error loading 'nutribone_effnet_model.h5' file from storage. Details: [Errno 2] Unable to synchronously open file (unable to open file: name = 'nutribone_effnet_model.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Falling back to active session model instance if available...
#
# Calculating perfectly aligned 1-to-1 validation metrics...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1723/2288010175.py in <cell line: 0>()
#      41
#      42 # 1. Force sequential ordering AND clean individual step sizing
# ---> 43 val_gen.shuffle = False
#      44 val_gen.batch_size = 1   # Fixes the remainder batch mismatch
#      45 val_gen.reset()
#
# NameError: name 'val_gen' is not defined
