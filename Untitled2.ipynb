# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahidrrs/Whatsapp-link-generator/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !unzip "/content/archive (4).zip" -d /content/dataset
# Out:
# unzip:  cannot find or open /content/archive (4).zip, /content/archive (4).zip.zip or /content/archive (4).zip.ZIP.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.17G/1.17G [00:08<00:00, 142MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset/versions/1

# %%
import os

base = path
print(os.listdir(base))
# Out:
# ['OS Collected Data']

# %%
import os

dataset_path = "/kaggle/input/multi-class-knee-osteoporosis-x-ray-dataset/OS Collected Data"
print(os.listdir(dataset_path))
# Out:
# ['Osteopenia', 'Osteoporosis', 'Normal']

# %%
import os

dataset_path = os.path.join(base, "OS Collected Data")

print(os.listdir(dataset_path))
# Out:
# ['Osteoporosis', 'Normal', 'Osteopenia']

# %%
from PIL import Image
import os

dataset_path = os.path.join(base, "OS Collected Data")

# Example: open first image in Normal
normal_folder = os.path.join(dataset_path, 'Normal')
first_image = os.listdir(normal_folder)[0]
image_path = os.path.join(normal_folder, first_image)

img = Image.open(image_path)
img.show()

# %%
import numpy as np
from PIL import Image

categories = ['Normal', 'Osteopenia', 'Osteoporosis']
data = []
labels = []

for category in categories:
    folder_path = os.path.join(dataset_path, category)
    for file in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file)
        try:
            img = Image.open(file_path).convert('RGB').resize((224,224))
            data.append(np.array(img))
            labels.append(category)
        except:
            print("Error loading", file_path)

data = np.array(data)
labels = np.array(labels)
print("Data shape:", data.shape)
print("Labels shape:", labels.shape)
# Out:
# Data shape: (1947, 224, 224, 3)
# Labels shape: (1947,)

# %%
print(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7CC062D93350>

# %%
import matplotlib.pyplot as plt
import random

# randomly ek image index choose kro
idx = random.randint(0, len(data) - 1)

# image aur label load kro
img = data[idx]
label = labels[idx]

plt.imshow(img.astype('uint8'))
plt.title(f"Label: {label}")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(223.5), np.float64(223.5), np.float64(-0.5))

# %%
import matplotlib.pyplot as plt
import random

idx = random.randint(0, len(data) - 1)

img = data[idx]
label = labels[idx]

plt.imshow(img.astype('uint8'))
plt.title(f"Label: {label}")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(223.5), np.float64(223.5), np.float64(-0.5))

# %%
dataset_path = "/kaggle/input/multi-class-knee-osteoporosis-x-ray-dataset/OS Collected Data"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
dataset_path = os.path.join(base, "OS Collected Data")

train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    zoom_range=0.1,
    horizontal_flip=True
)

# --- Start of diagnostic additions ---
print(f"Verifying dataset_path: {dataset_path}")
if not os.path.exists(dataset_path):
    print(f"Error: The directory '{dataset_path}' does not exist.")
else:
    print(f"Success: The directory '{dataset_path}' exists.")
    try:
        # Attempt to list directory contents to further diagnose access issues
        contents = os.listdir(dataset_path)
        print(f"Contents of '{dataset_path}': First 5 items: {contents[:5]}")
        if not any(os.path.isdir(os.path.join(dataset_path, item)) for item in contents):
            print("Warning: No subdirectories found in dataset_path. `flow_from_directory` expects class subfolders.")
    except FileNotFoundError as e:
        print(f"Error: Still unable to list contents of '{dataset_path}'. Original error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred while trying to list directory contents: {e}")
# --- End of diagnostic additions ---

train_gen = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_gen = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Verifying dataset_path: /root/.cache/kagglehub/datasets/mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset/versions/1/OS Collected Data
# Success: The directory '/root/.cache/kagglehub/datasets/mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset/versions/1/OS Collected Data' exists.
# Contents of '/root/.cache/kagglehub/datasets/mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset/versions/1/OS Collected Data': First 5 items: ['Osteoporosis', 'Normal', 'Osteopenia']
# Found 1559 images belonging to 3 classes.
# Found 388 images belonging to 3 classes.

# %%
#model traning
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# %%
base = EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

base.trainable = False   # freeze feature extractor
# Out:
# ...
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x = GlobalAveragePooling2D()(base.output)
x = Dropout(0.3)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
output = Dense(train_gen.num_classes, activation='softmax')(x)

model = Model(inputs=base.input, outputs=output)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 224, 224,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=10
)
# Out:
# Epoch 1/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.3836 - loss: 1.1037 - val_accuracy: 0.4072 - val_loss: 1.0504
# Epoch 2/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.4047 - loss: 1.0613 - val_accuracy: 0.4021 - val_loss: 1.0521
# Epoch 3/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4047 - loss: 1.0578 - val_accuracy: 0.4021 - val_loss: 1.0483
# Epoch 4/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4067 - loss: 1.0546 - val_accuracy: 0.4072 - val_loss: 1.0497
# Epoch 5/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.4112 - loss: 1.0522 - val_accuracy: 0.4021 - val_loss: 1.0505
# Epoch 6/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.4028 - loss: 1.0560 - val_accuracy: 0.4072 - val_loss: 1.0498
# Epoch 7/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.4047 - loss: 1.0542 - val_accuracy: 0.4072 - val_loss: 1.0571
# Epoch 8/10
# ...

# %%
model.save("nutribone_effnet_model.h5")
print("Model Saved!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Saved!

# %%
#Stage 2,
#Evaluate model (accuracy, loss, plots, confusion matrix, classification report)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# history from model.fit
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(); plt.title('Loss')

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.legend(); plt.title('Accuracy')
plt.show()

# Get true labels and preds on validation set
val_gen.reset()
preds = model.predict(val_gen, verbose=1)
y_pred = np.argmax(preds, axis=1)
y_true = val_gen.classes
class_names = list(val_gen.class_indices.keys())

print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted'); plt.ylabel('True'); plt.title('Confusion Matrix')
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step
#               precision    recall  f1-score   support
#
#       Normal       0.40      1.00      0.57       156
#   Osteopenia       0.00      0.00      0.00        74
# Osteoporosis       0.00      0.00      0.00       158
#
#     accuracy                           0.40       388
#    macro avg       0.13      0.33      0.19       388
# weighted avg       0.16      0.40      0.23       388
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
#model failed, wapas kaam krte h
#ab base model unfreeze karenge

# %%
base.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_ft = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=5
)

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_gen.classes),
    y=train_gen.classes
)

class_weights = dict(enumerate(class_weights))
class_weights

# %%
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=10,
    class_weight=class_weights
)

# %%
batch_size = 16

# %%
import matplotlib.pyplot as plt

# history = history or history_ft depending on which run you finished last
h = history  # replace with history_ft if you ran fine-tune separately

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(h.history['loss'], label='train_loss')
plt.plot(h.history['val_loss'], label='val_loss')
plt.legend(); plt.title('Loss')

plt.subplot(1,2,2)
plt.plot(h.history['accuracy'], label='train_acc')
plt.plot(h.history['val_accuracy'], label='val_acc')
plt.legend(); plt.title('Accuracy')

plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# make sure val_gen is reset so ordering matches
val_gen.reset()
preds = model.predict(val_gen, verbose=1)
y_pred = np.argmax(preds, axis=1)
y_true = val_gen.classes
class_names = list(val_gen.class_indices.keys())

print(classification_report(y_true, y_pred, target_names=class_names, zero_division=0))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted'); plt.ylabel('True'); plt.title('Confusion Matrix')
plt.show()

# %%
# isme sbko osteoprosis predict kr rha h
# Matlab agar 100 Normal X-ray do, model sirf 22 sahi bata raha hai.

# This makes the model unsafe for medical usage, because Normal ko disease bata dena huge problem hai.

# %%
base.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history_ft = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=20,       # IMPORTANT
    class_weight=class_weights
)

# %%
import matplotlib.pyplot as plt

h = history_ft  # fine-tuned history

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(h.history['loss'], label='train_loss')
plt.plot(h.history['val_loss'], label='val_loss')
plt.legend(); plt.title('Loss After Fine-Tuning')

plt.subplot(1,2,2)
plt.plot(h.history['accuracy'], label='train_acc')
plt.plot(h.history['val_accuracy'], label='val_acc')
plt.legend(); plt.title('Accuracy After Fine-Tuning')

plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

val_gen.reset()
preds = model.predict(val_gen)
y_pred = np.argmax(preds, axis=1)
y_true = val_gen.classes
class_names = list(val_gen.class_indices.keys())

print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted"); plt.ylabel("True")
plt.show()

# %%
errors = np.where(y_pred != y_true)[0]

for i in errors[:10]:  # first 10 mistakes
    print("True:", class_names[y_true[i]], "Pred:", class_names[y_pred[i]])
    img = plt.imread(val_gen.filepaths[i])
    plt.imshow(img); plt.axis('off')
    plt.show()

# %%
# Is baar Osteopenia ka recall 65% ho gaya (jo pehle 7% tha),
# par Osteoporosis ka recall 5% pe gir gaya (jo pehle 67% tha).
# Class Shift Problem bolte h isko
#sbko osteoponia hi predict kr rha

# %%
# ab kya karenge??
# CLASS WEIGHTS KO REMOVE KAR DO

# %%
history_ft2 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=10,
    # NO CLASS WEIGHTS
)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model.save('/content/drive/MyDrive/nutribone_effnet_model.h5')
print("Model Saved in Drive!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Saved in Drive!

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# from tensorflow.keras.models import load_model
# model = load_model('/content/drive/MyDrive/nutribone_effnet_model.h5')
# print("Model Loaded!")
